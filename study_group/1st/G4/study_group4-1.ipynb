# %% [markdown]
# # 引入套件

# %%
import pandas as pd
import jieba.analyse
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import matplotlib.font_manager as font_manager

# %% [markdown]
# # 1. 設定 Matplotlib 中文字體

# %%
# Path to the custom font
font_path = 'font/TraditionalChinese.ttf'

# Add the custom font to the font manager
font_manager.fontManager.addfont(font_path)

# After adding the font, search for it by filename to get the correct font name
for font in font_manager.fontManager.ttflist:
    if font.fname == font_path:
        print(f"Found font: {font.name}")
        plt.rcParams['font.family'] = font.name
        break
# Out:
# Found font: Noto Sans TC

# %% [markdown]
# ## 2. PPT 台積電相關貼文

# %% [markdown]
# 網路爬蟲的技術不會在此範例中討論，在後續的範例中，我們將以爬取下來的PTT文章來說明文字分析的技術。

# %% [markdown]
# ### 2.1 資料介紹
# 資料來源：
# + 工作流程平台蒐集PTT 股票版(Stock)文章
# + 關鍵字：「台積電」
# + 時間： 2023-03-20 ~ 2023-03-20
# + 資料筆數：共 2775 篇文章

# %% [markdown]
# 讀取 ptt 檔案zh_buffet_20_22.csv

# %%
df = pd.read_csv('data/raw_data.csv')
df
# Out:
#       system_id                                             artUrl  \
# 0             1  https://www.ptt.cc/bbs/Stock/M.1679279576.A.D7...
# 1             2  https://www.ptt.cc/bbs/Stock/M.1679289787.A.D6...
# 2             3  https://www.ptt.cc/bbs/Stock/M.1679292328.A.BC...
# 3             4  https://www.ptt.cc/bbs/Stock/M.1679299901.A.73...
# 4             5  https://www.ptt.cc/bbs/Stock/M.1679304839.A.E6...
# ...         ...                                                ...
# 2770       2771  https://www.ptt.cc/bbs/Stock/M.1710843746.A.03...
# 2771       2772  https://www.ptt.cc/bbs/Stock/M.1710851717.A.B6...
# 2772       2773  https://www.ptt.cc/bbs/Stock/M.1710856327.A.44...
# 2773       2774  https://www.ptt.cc/bbs/Stock/M.1710862323.A.84...
# 2774       2775  https://www.ptt.cc/bbs/Stock/M.1710863318.A.22...
#
#                        artTitle              artDate    artPoster artCatagory  \
# 0        [標的]00712富時不動產天天大溢價要賣？  2023-03-20 10:32:54        ATF91       Stock
# 1       [新聞]金融存股勇士進場了！9家金控股東人數創  2023-03-20 13:23:04  black1x2y3z       Stock
# 2               [標的]2753八方雲集鍋貼空  2023-03-20 14:05:26        Timzy       Stock
# 3             [情報]0320上市外資買賣超排行  2023-03-20 16:11:39   saber50116       Stock
# 4     [情報]6667信紘科111年5.11股利4.24  2023-03-20 17:33:57     a0808996       Stock
# ...                         ...                  ...          ...         ...
# 2770                 [標的]ADM.US  2024-03-19 18:22:22     yamakazi       Stock
# 2771     [新聞]賴清德向竹科半導體業掛保證維持兩岸和  2024-03-19 20:35:14      humbler       Stock
# 2772       [情報]113年03月19日信用交易統計  2024-03-19 21:52:04   steward135       Stock
# 2773      [情報]0319上市櫃外資投信買超金額排行  2024-03-19 23:32:00  steveisaman       Stock
# 2774         [標的]6667信紘科海外擴大營運多  2024-03-19 23:48:36      wangggg       Stock
#
#                                              artContent  \
# 0     1. 標的： 00712 富時不動產\r\n(例 2330.TW 台積電)\r\n2. 分類...
# 1     原文標題：金融存股勇士進場了！9家金控股東人數創史上新高\r\n原文連結：\r\nhttps...
# 2     -\r\n1.發標的文未充實內文，\r\n多空理由不充實\r\n者，板規1-1-5或4-4處...
# 3     1. 標題：外資買賣超排行\r\n\r\n2. 來源：台灣證交所\r\n\r\n3. 網址：...
# 4     https://mops.twse.com.tw/mops/web/t146sb05\r\n...
# ...                                                 ...
# 2770  -\r\n1.發標的文未充實內文，\r\n多空理由不充實\r\n者，板規1-1-5或4-4處...
# 2771  原文標題：\r\n賴清德向竹科半導體業掛保證 維持兩岸和平「水電不用擔心」\r\n\r\n原...
# 2772  1. 標題：113年03月19日信用交易統計\r\n2. 來源：臺灣證券交易所、證券櫃檯買賣...
# 2773  外資\r\n\r\n排行  股票名稱     百萬   收盤價   漲跌\r\n\r\n1 ...
# 2774  1. 標的： 6667 信紘科\r\n\r\n2. 分類：多/空/請益/心得\r\n\r\n...
#
#                                              artComment             e_ip  \
# 0     [{"cmtStatus": "→", "cmtPoster": "hebeisme5566...    42.77.223.199
# 1     [{"cmtStatus": "推", "cmtPoster": "maxdi", "cmt...  140.121.145.184
# 2     [{"cmtStatus": "推", "cmtPoster": "zxcv91039", ...  223.141.185.139
# 3     [{"cmtStatus": "推", "cmtPoster": "powerkshs", ...   111.255.56.173
# 4     [{"cmtStatus": "推", "cmtPoster": "PeaceBoy", "...   123.194.132.40
# ...                                                 ...              ...
# 2770  [{"cmtStatus": "推", "cmtPoster": "gs13010", "c...     1.200.104.88
# 2771  [{"cmtStatus": "推", "cmtPoster": "nvlsvee", "c...  111.251.205.175
# 2772  [{"cmtStatus": "推", "cmtPoster": "hong92", "cm...    36.224.121.61
# 2773  [{"cmtStatus": "推", "cmtPoster": "fernmmm", "c...     36.234.75.22
# 2774  [{"cmtStatus": "推", "cmtPoster": "tgm0952", "c...     39.15.48.172
#
#              insertedDate dataSource
# 0     2023-03-21 02:21:44        ptt
# 1     2023-03-21 02:21:44        ptt
# 2     2023-03-21 02:21:49        ptt
# 3     2023-03-21 02:21:49        ptt
# 4     2023-03-21 02:21:53        ptt
# ...                   ...        ...
# 2770  2024-03-20 02:05:23        ptt
# 2771  2024-03-20 02:05:27        ptt
# 2772  2024-03-20 02:05:31        ptt
# 2773  2024-03-20 02:05:31        ptt
# 2774  2024-03-20 02:05:31        ptt
#
# [2775 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2775 entries, 0 to 2774
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   system_id     2775 non-null   int64
#  1   artUrl        2775 non-null   object
#  2   artTitle      2775 non-null   object
#  3   artDate       2775 non-null   object
#  4   artPoster     2775 non-null   object
#  5   artCatagory   2775 non-null   object
#  6   artContent    2771 non-null   object
#  7   artComment    2775 non-null   object
#  8   e_ip          2619 non-null   object
#  9   insertedDate  2775 non-null   object
#  10  dataSource    2775 non-null   object
# dtypes: int64(1), object(10)
# memory usage: 238.6+ KB

# %% [markdown]
# ### 2.2 資料初步清理
# - 清除內文為空值的文章
#
# - 透過觀察發現ptt的文章常用兩個換行符號作為句子的結尾，因此將兩個換行取代為句號。
#
# - 清除不重要的字如換行、網址

# %%
clear_df = df.copy()

#去除本次不會用到的欄位
drop_cols = ['system_id', 'artUrl', 'artPoster', 'artCatagory', 'artComment', 'e_ip', 'insertedDate', 'dataSource']
clear_df.drop(drop_cols, axis = 1, inplace = True)

#去除文章內容為空值的筆數
clear_df.dropna(subset = ['artContent'], axis=0, how='any', inplace=True)

#新增['sentence']欄位，用'。'取代'\n\n'，並移除'\n'
clear_df['sentence'] = clear_df['artContent'].str.replace(r'\n\n','。', regex=True)
clear_df['sentence'] = clear_df['sentence'].str.replace(r'\n','，', regex=True)

#移除內文中的網址
clear_df['sentence'] = clear_df['sentence'].replace(r'http\S+', '', regex=True).replace(r'www\S+', '', regex=True)

clear_df.head(10)
# Out:
#                     artTitle              artDate  \
# 0     [標的]00712富時不動產天天大溢價要賣？  2023-03-20 10:32:54
# 1    [新聞]金融存股勇士進場了！9家金控股東人數創  2023-03-20 13:23:04
# 2            [標的]2753八方雲集鍋貼空  2023-03-20 14:05:26
# 3          [情報]0320上市外資買賣超排行  2023-03-20 16:11:39
# 4  [情報]6667信紘科111年5.11股利4.24  2023-03-20 17:33:57
# 5   [情報]112/03/20八大公股銀行買賣超排行  2023-03-20 18:28:43
# 6        [標的]敦泰3545多重啟多頭循環炒作  2023-03-20 21:19:26
# 7       [情報]112年03月20日信用交易統計  2023-03-20 21:47:15
# 8              Re:[標的]SCHWUS  2023-03-20 22:38:43
# 9                 [標的]NDAQUS  2023-03-20 23:23:34
#
#                                           artContent  \
# 0  1. 標的： 00712 富時不動產\r\n(例 2330.TW 台積電)\r\n2. 分類...
# 1  原文標題：金融存股勇士進場了！9家金控股東人數創史上新高\r\n原文連結：\r\nhttps...
# 2  -\r\n1.發標的文未充實內文，\r\n多空理由不充實\r\n者，板規1-1-5或4-4處...
# 3  1. 標題：外資買賣超排行\r\n\r\n2. 來源：台灣證交所\r\n\r\n3. 網址：...
# 4  https://mops.twse.com.tw/mops/web/t146sb05\r\n...
# 5  1. 標題：112/03/20 八大公股銀行買賣超排行\r\n\r\n2. 來源：玩股網\r...
# 6  -\r\n1.發標的文未充實內文，\r\n多空理由不充實\r\n者，板規1-1-5或4-4處...
# 7  1. 標題：112年03月20日信用交易統計\r\n2. 來源：臺灣證券交易所、證券櫃檯買賣...
# 8  後來賣出觀察了一下\r\n\r\n發現他似乎衝不太破59這個關卡\r\n\r\n但到53 5...
# 9  1. 標的：\r\n(例 2330.TW 台積電)\r\nNDAQ US\r\n\r\n2....
#
#                                             sentence
# 0  1. 標的： 00712 富時不動產\r，(例 2330.TW 台積電)\r，2. 分類：討...
# 1  原文標題：金融存股勇士進場了！9家金控股東人數創史上新高\r，原文連結：\r，\r，發布時間...
# 2  -\r，1.發標的文未充實內文，\r，多空理由不充實\r，者，板規1-1-5或4-4處份\r...
# 3  1. 標題：外資買賣超排行\r，\r，2. 來源：台灣證交所\r，\r，3. 網址：\r，\...
# 4  \r，1.提報董事會或經董事會決議日期:112/03/20\r，2.審計委員會通過日期:11...
# 5  1. 標題：112/03/20 八大公股銀行買賣超排行\r，\r，2. 來源：玩股網\r，\...
# 6  -\r，1.發標的文未充實內文，\r，多空理由不充實\r，者，板規1-1-5或4-4處份\r...
# 7  1. 標題：112年03月20日信用交易統計\r，2. 來源：臺灣證券交易所、證券櫃檯買賣中...
# 8  後來賣出觀察了一下\r，\r，發現他似乎衝不太破59這個關卡\r，\r，但到53 54這邊又...
# 9  1. 標的：\r，(例 2330.TW 台積電)\r，NDAQ US\r，\r，2. 分類：...

# %% [markdown]
# ### 2.3 斷句
# 中文主要以標點符號進行斷句，並清除空的字串

# %%
clear_df['sentence'] = clear_df['sentence'].str.split("[,，。！!？?]{1,}")

sent_df = clear_df.explode('sentence').reset_index(drop=True)

sent_df.head(10)
# Out:
#                  artTitle              artDate  \
# 0  [標的]00712富時不動產天天大溢價要賣？  2023-03-20 10:32:54
# 1  [標的]00712富時不動產天天大溢價要賣？  2023-03-20 10:32:54
# 2  [標的]00712富時不動產天天大溢價要賣？  2023-03-20 10:32:54
# 3  [標的]00712富時不動產天天大溢價要賣？  2023-03-20 10:32:54
# 4  [標的]00712富時不動產天天大溢價要賣？  2023-03-20 10:32:54
# 5  [標的]00712富時不動產天天大溢價要賣？  2023-03-20 10:32:54
# 6  [標的]00712富時不動產天天大溢價要賣？  2023-03-20 10:32:54
# 7  [標的]00712富時不動產天天大溢價要賣？  2023-03-20 10:32:54
# 8  [標的]00712富時不動產天天大溢價要賣？  2023-03-20 10:32:54
# 9  [標的]00712富時不動產天天大溢價要賣？  2023-03-20 10:32:54
#
#                                           artContent              sentence
# 0  1. 標的： 00712 富時不動產\r\n(例 2330.TW 台積電)\r\n2. 分類...  1. 標的： 00712 富時不動產\r
# 1  1. 標的： 00712 富時不動產\r\n(例 2330.TW 台積電)\r\n2. 分類...     (例 2330.TW 台積電)\r
# 2  1. 標的： 00712 富時不動產\r\n(例 2330.TW 台積電)\r\n2. 分類...            2. 分類：討論\r
# 3  1. 標的： 00712 富時不動產\r\n(例 2330.TW 台積電)\r\n2. 分類...                    \r
# 4  1. 標的： 00712 富時不動產\r\n(例 2330.TW 台積電)\r\n2. 分類...           3. 分析/正文：\r
# 5  1. 標的： 00712 富時不動產\r\n(例 2330.TW 台積電)\r\n2. 分類...                    \r
# 6  1. 標的： 00712 富時不動產\r\n(例 2330.TW 台積電)\r\n2. 分類...      這隻已經超過一周都大溢價8~9趴
# 7  1. 標的： 00712 富時不動產\r\n(例 2330.TW 台積電)\r\n2. 分類...             股價卻沒有急速下跌
# 8  1. 標的： 00712 富時不動產\r\n(例 2330.TW 台積電)\r\n2. 分類...           是每天凌遲你那種小小跌
# 9  1. 標的： 00712 富時不動產\r\n(例 2330.TW 台積電)\r\n2. 分類...                   明\r

# %% [markdown]
# ### 2.4 斷詞
# 斷詞引擎設定：使用 Jieba 當作斷詞系統。
# Jieba原先內建為簡體字字典，但我們可以使用繁體字典來做為替換，結果會比較好。
# 另外可能還有一些專有名詞是沒有被包含在預設字典當中，我們也可以使用自定義字典的方式加入，或者使用參數的形式帶入。

# %%
# 初始化斷詞引擎：不一定要設定，只使用內建效果也可以
# 參考網址：https://raw.githubusercontent.com/ldkrsi/jieba-zh_TW/master/jieba/dict.txt
jieba.set_dictionary('dict/dict.txt')

# %% [markdown]
# 斷詞前先將標點符號清除，並清除空字串

# %% [markdown]
# ***正規表達式 (Regular Expression)*** 是透過簡單的特定字符規則，從文本中找尋符合對應規則的字串，幾乎常見的程式語言，都有支援正規表達式的操作。
#
# 以下提供幾個範例：
#
# + ```\d```：匹配任何一個數字字符，等同於 [0-9]
#
# + ```\w```：匹配任何一個單詞字符，包括字母、數字和下劃線，等同於 [a-zA-Z0-9_]
#
# + ```\s```：匹配任何一個空白字符，包括空格、換行等
#
# + ```[ ]```：用於定義一個字符集合，匹配集合中的任何一個字符。 例如: [abc] = 匹配字符 a、b 或 c。
#
# + ```[^ ]```：用於定義一個否定字符集合，匹配不在集合中的任何一個字符。 例如: [^abc] = 匹配除了 a、b 和 c 以外的任何字符。
#
# + ```+```：匹配前面提及的元素一次或多次。
#
# 更多有關正規表達式的用法可參考python官網的[介紹](https://docs.python.org/zh-tw/3/library/re.html)

# %%
#去除句子中除了字母、數字、空白字符以外的符號
sent_df['sentence'] = sent_df['sentence'].str.replace(r'[^\w\s]+|[\d]', '', regex=True).astype(str)

# 把長度小於1的sentence刪掉
sent_df = sent_df[sent_df["sentence"].str.len() > 1]

sent_df.head(10)
# Out:
#                   artTitle              artDate  \
# 0   [標的]00712富時不動產天天大溢價要賣？  2023-03-20 10:32:54
# 1   [標的]00712富時不動產天天大溢價要賣？  2023-03-20 10:32:54
# 2   [標的]00712富時不動產天天大溢價要賣？  2023-03-20 10:32:54
# 4   [標的]00712富時不動產天天大溢價要賣？  2023-03-20 10:32:54
# 6   [標的]00712富時不動產天天大溢價要賣？  2023-03-20 10:32:54
# 7   [標的]00712富時不動產天天大溢價要賣？  2023-03-20 10:32:54
# 8   [標的]00712富時不動產天天大溢價要賣？  2023-03-20 10:32:54
# 9   [標的]00712富時不動產天天大溢價要賣？  2023-03-20 10:32:54
# 10  [標的]00712富時不動產天天大溢價要賣？  2023-03-20 10:32:54
# 11  [標的]00712富時不動產天天大溢價要賣？  2023-03-20 10:32:54
#
#                                            artContent       sentence
# 0   1. 標的： 00712 富時不動產\r\n(例 2330.TW 台積電)\r\n2. 分類...    標的  富時不動產\r
# 1   1. 標的： 00712 富時不動產\r\n(例 2330.TW 台積電)\r\n2. 分類...     例 TW 台積電\r
# 2   1. 標的： 00712 富時不動產\r\n(例 2330.TW 台積電)\r\n2. 分類...         分類討論\r
# 4   1. 標的： 00712 富時不動產\r\n(例 2330.TW 台積電)\r\n2. 分類...         分析正文\r
# 6   1. 標的： 00712 富時不動產\r\n(例 2330.TW 台積電)\r\n2. 分類...  這隻已經超過一周都大溢價趴
# 7   1. 標的： 00712 富時不動產\r\n(例 2330.TW 台積電)\r\n2. 分類...      股價卻沒有急速下跌
# 8   1. 標的： 00712 富時不動產\r\n(例 2330.TW 台積電)\r\n2. 分類...    是每天凌遲你那種小小跌
# 9   1. 標的： 00712 富時不動產\r\n(例 2330.TW 台積電)\r\n2. 分類...            明\r
# 10  1. 標的： 00712 富時不動產\r\n(例 2330.TW 台積電)\r\n2. 分類...            天除息
# 11  1. 標的： 00712 富時不動產\r\n(例 2330.TW 台積電)\r\n2. 分類...    整年殖利率可能有趴以上

# %% [markdown]
# 使用jieba進行斷詞

# %%
word_df = sent_df.assign(word = sent_df['sentence'].apply(jieba.lcut)).explode('word').drop(['sentence'], axis=1)

#去除少於兩個字的詞語
word_df = word_df.loc[word_df['word'].str.len() > 1]

word_df.head(10)
# Out:
# Building prefix dict from C:\Users\eddie\GitHub\StockNatrakLanguageAnalyze\dict\dict.txt ...
# Loading model from cache C:\Users\eddie\AppData\Local\Temp\jieba.u7ed60b131b91313bb12d624d6950b4ca.cache
# Loading model cost 0.534 seconds.
# Prefix dict has been built successfully.
#                  artTitle              artDate  \
# 0  [標的]00712富時不動產天天大溢價要賣？  2023-03-20 10:32:54
# 0  [標的]00712富時不動產天天大溢價要賣？  2023-03-20 10:32:54
# 0  [標的]00712富時不動產天天大溢價要賣？  2023-03-20 10:32:54
# 1  [標的]00712富時不動產天天大溢價要賣？  2023-03-20 10:32:54
# 1  [標的]00712富時不動產天天大溢價要賣？  2023-03-20 10:32:54
# 2  [標的]00712富時不動產天天大溢價要賣？  2023-03-20 10:32:54
# 2  [標的]00712富時不動產天天大溢價要賣？  2023-03-20 10:32:54
# 4  [標的]00712富時不動產天天大溢價要賣？  2023-03-20 10:32:54
# 4  [標的]00712富時不動產天天大溢價要賣？  2023-03-20 10:32:54
# 6  [標的]00712富時不動產天天大溢價要賣？  2023-03-20 10:32:54
#
#                                           artContent word
# 0  1. 標的： 00712 富時不動產\r\n(例 2330.TW 台積電)\r\n2. 分類...   標的
# 0  1. 標的： 00712 富時不動產\r\n(例 2330.TW 台積電)\r\n2. 分類...   富時
# 0  1. 標的： 00712 富時不動產\r\n(例 2330.TW 台積電)\r\n2. 分類...  不動產
# 1  1. 標的： 00712 富時不動產\r\n(例 2330.TW 台積電)\r\n2. 分類...   TW
# 1  1. 標的： 00712 富時不動產\r\n(例 2330.TW 台積電)\r\n2. 分類...  台積電
# 2  1. 標的： 00712 富時不動產\r\n(例 2330.TW 台積電)\r\n2. 分類...   分類
# 2  1. 標的： 00712 富時不動產\r\n(例 2330.TW 台積電)\r\n2. 分類...   討論
# 4  1. 標的： 00712 富時不動產\r\n(例 2330.TW 台積電)\r\n2. 分類...   分析
# 4  1. 標的： 00712 富時不動產\r\n(例 2330.TW 台積電)\r\n2. 分類...   正文
# 6  1. 標的： 00712 富時不動產\r\n(例 2330.TW 台積電)\r\n2. 分類...   已經

# %% [markdown]
# #### 為了進行前後比較，先透過繪製詞頻圖及文字雲觀察一下目前的資料。

# %% [markdown]
# ### 2.5 計算去除停用字及更新字典前的詞頻

# %%
freq_df = pd.DataFrame(pd.value_counts(word_df['word'])).sort_values(by = ['count'], ascending = False).reset_index()
freq_df.head(10)
# Out:
# C:\Users\eddie\AppData\Local\Temp\ipykernel_36952\3460779582.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   freq_df = pd.DataFrame(pd.value_counts(word_df['word'])).sort_values(by = ['count'], ascending = False).reset_index()
#   word  count
# 0  台積電   7999
# 1   台灣   3787
# 2   原文   2856
# 3   AI   2385
# 4   元大   1862
# 5   晶片   1843
# 6  半導體   1834
# 7   公司   1817
# 8   市場   1731
# 9   標題   1728

# %% [markdown]
# ### 2.6 視覺化結果

# %% [markdown]
# matplotlib 畫圖中文顯示不出來的問題
#
# * Mac : <a href="https://blog.csdn.net/RivenDong/article/details/118990773">參考方式</a>
# * Windows : <a href="https://medium.com/marketingdatascience/%E8%A7%A3%E6%B1%BApython-3-matplotlib%E8%88%87seaborn%E8%A6%96%E8%A6%BA%E5%8C%96%E5%A5%97%E4%BB%B6%E4%B8%AD%E6%96%87%E9%A1%AF%E7%A4%BA%E5%95%8F%E9%A1%8C-f7b3773a889b">參考方式</a>
# * 暫存查找 path 方式：matplotlib.get_cachedir()

# %% [markdown]
# #### 繪製詞頻為前10高的長條圖

# %%
freq_df.head(10).plot.barh(x = 'word', y = 'count').invert_yaxis()
plt.show()

# %% [markdown]
# #### 繪製文字雲

# %%
# wordcloud的輸入須為dict，因此先將freq_df轉換成成dict
freq_dict = freq_df.set_index('word').to_dict()
freq_dict = freq_dict['count']

freq_dict
# Out:
# {'台積電': 7999,
#  '台灣': 3787,
#  '原文': 2856,
#  'AI': 2385,
#  '元大': 1862,
#  '晶片': 1843,
#  '半導體': 1834,
#  '公司': 1817,
#  '市場': 1731,
#  '標題': 1728,
#  '台股': 1684,
#  '投資': 1629,
#  '美國': 1617,
#  '奈米': 1479,
#  '今年': 1409,
#  '外資': 1404,
#  '內容': 1384,
#  '股息': 1383,
#  '心得': 1372,
#  '時間': 1335,
#  '記者': 1296,
#  '排行': 1279,
#  '營收': 1259,
#  '國泰': 1223,
#  '股價': 1218,
#  '股票': 1203,
#  '製程': 1187,
#  '標的': 1185,
#  '中國': 1138,
#  '表示': 1070,
#  '發布': 1058,
#  '資增': 1037,
#  'KY': 1028,
#  '產業': 1021,
#  '券增': 1014,
#  '買超': 1006,
#  '可能': 1000,
#  '目前': 999,
#  '連結': 994,
#  '賣超': 985,
#  '指數': 983,
#  '評論': 980,
#  '來源': 975,
#  '交易': 954,
#  '就是': 937,
#  '署名': 924,
#  '長期': 919,
#  '技術': 918,
#  '可以': 896,
#  '富邦': 893,
#  '現在': 882,
#  'ETF': 877,
#  '緯創': 874,
#  '美債': 865,
#  '億元': 848,
#  '聯電': 837,
#  '成長': 830,
#  '先進': 826,
#  '需求': 824,
#  '科技': 824,
#  '機制': 807,
#  '未來': 807,
#  'TW': 785,
#  '全球': 783,
#  '內文': 772,
#  '投信': 767,
#  '沒有': 767,
#  '去年': 763,
#  '指出': 760,
#  '客戶': 751,
#  '預期': 749,
#  '廣達': 744,
#  '以上': 741,
#  '證券': 728,
#  '聯發科': 719,
#  '持續': 719,
#  '網址': 719,
#  '報導': 706,
#  '輝達': 702,
#  '開始': 684,
#  '第一': 678,
#  '停損': 678,
#  '日本': 659,
#  '晶圓': 656,
#  '分析': 647,
#  '三星': 647,
#  '美元': 645,
#  '億美': 644,
#  '鴻海': 637,
#  '分類': 633,
#  '今天': 630,
#  '討論': 628,
#  '買賣': 628,
#  '退場': 622,
#  '張數': 615,
#  '獲利': 608,
#  '已經': 606,
#  '因為': 605,
#  '認為': 604,
#  '金額': 592,
#  '產能': 588,
#  '長榮': 587,
#  '還是': 584,
#  '政府': 583,
#  '投控': 573,
#  '問題': 562,
#  '如果': 559,
#  '相關': 555,
#  '不是': 555,
#  '成交量': 554,
#  '代工': 549,
#  '影響': 549,
#  '我們': 545,
#  '英特爾': 544,
#  '中信': 544,
#  '資料': 543,
#  '企業': 540,
#  '生產': 536,
#  '格式': 532,
#  '超過': 530,
#  '不過': 530,
#  '上漲': 530,
#  '所以': 521,
#  '以下': 521,
#  '應該': 516,
#  '統計': 505,
#  '復華': 504,
#  '漲跌': 503,
#  '一個': 495,
#  '蘋果': 495,
#  '排名': 491,
#  '台積': 491,
#  '今日': 491,
#  '市值': 490,
#  '正文': 487,
#  '表現': 486,
#  '供應鏈': 469,
#  '主要': 469,
#  '手機': 460,
#  '機會': 457,
#  '永續': 456,
#  '持股': 453,
#  '增加': 451,
#  '技嘉': 450,
#  '合作': 445,
#  '發展': 444,
#  '自己': 444,
#  '產品': 440,
#  '長榮航': 438,
#  '資金': 438,
#  '經濟': 434,
#  '法人': 430,
#  '成本': 429,
#  '明年': 426,
#  '買進': 425,
#  '比較': 422,
#  '大家': 421,
#  '使用': 411,
#  '高息': 411,
#  '名稱': 410,
#  '日月光': 404,
#  '製造': 399,
#  '股市': 396,
#  '欣興': 396,
#  '包括': 395,
#  '不會': 390,
#  '群創': 389,
#  '還有': 389,
#  '預計': 386,
#  '中信金': 386,
#  '投資人': 385,
#  '智慧': 384,
#  '美股': 381,
#  '封裝': 381,
#  '群益': 381,
#  '成為': 372,
#  '知道': 372,
#  '力積': 371,
#  '漲停': 371,
#  '因此': 369,
#  '計畫': 369,
#  '英業達': 368,
#  '臺灣': 368,
#  '雖然': 367,
#  '調整': 364,
#  '輸入': 364,
#  '必須': 363,
#  '真的': 360,
#  '大盤': 358,
#  '信用': 358,
#  '板規': 357,
#  '第季': 357,
#  '下跌': 357,
#  '收盤價': 355,
#  '充實': 353,
#  '庫存': 353,
#  '加上': 352,
#  '看好': 351,
#  'ex': 351,
#  '中鋼': 350,
#  '很多': 349,
#  '量產': 348,
#  '電子': 348,
#  '開發金': 347,
#  '設備': 347,
#  '訂單': 346,
#  '國際': 345,
#  '預估': 344,
#  '以及': 342,
#  '華邦電': 340,
#  '根據': 339,
#  '中心': 338,
#  '股利': 337,
#  '大漲': 337,
#  '融資': 336,
#  '宏碁': 336,
#  '漲幅': 336,
#  '仁寶': 335,
#  '重要': 334,
#  '近期': 332,
#  '統一': 329,
#  '這樣': 329,
#  '銀行': 328,
#  '最近': 328,
#  '這個': 327,
#  '但是': 325,
#  '設計': 324,
#  '配息': 324,
#  '友達': 324,
#  '多空': 323,
#  '伺服器': 323,
#  '股東': 323,
#  '單位': 322,
#  '智原': 320,
#  '進場': 318,
#  '奇鋐': 317,
#  '法說': 315,
#  '國泰金': 314,
#  '下半年': 313,
#  '新高': 313,
#  '個股': 313,
#  '風險': 313,
#  '繼續': 310,
#  '永豐金': 310,
#  '營運': 309,
#  '光寶科': 308,
#  '基金': 308,
#  '財報': 307,
#  '資本': 305,
#  '出現': 305,
#  '陽明': 304,
#  '廠商': 304,
#  '需要': 303,
#  '自營商': 301,
#  '資訊': 298,
#  '世界': 297,
#  '兆豐金': 297,
#  '對於': 296,
#  '其中': 295,
#  '歷史': 294,
#  '特斯拉': 293,
#  '過去': 292,
#  '進行': 292,
#  '看到': 291,
#  '帶動': 291,
#  '應用': 291,
#  '這些': 290,
#  '價格': 290,
#  '消息': 289,
#  '華通': 288,
#  '優息': 286,
#  '百萬': 286,
#  '元大金': 285,
#  '提供': 285,
#  '京元電': 285,
#  '聯詠': 283,
#  '維持': 282,
#  '目標價': 279,
#  '玉山金': 277,
#  '公布': 275,
#  '可望': 275,
#  '餘額': 274,
#  '以來': 273,
#  '華航': 273,
#  'GPU': 273,
#  '之後': 273,
#  '台達電': 272,
#  '電動車': 271,
#  '新聞': 271,
#  '覺得': 270,
#  '創意': 269,
#  '人工': 269,
#  '光電': 269,
#  '台泥': 269,
#  '甚至': 268,
#  '業者': 267,
#  'ADR': 267,
#  '關鍵': 266,
#  '同時': 266,
#  '櫃買': 266,
#  '南亞科': 262,
#  '台指': 261,
#  '數據': 261,
#  '富邦金': 260,
#  '突破': 260,
#  '分析師': 259,
#  '直接': 258,
#  '發現': 258,
#  '怎麼': 257,
#  '董事長': 255,
#  '情況': 253,
#  '只是': 253,
#  '其實': 253,
#  '一直': 251,
#  '現金': 250,
#  '由於': 249,
#  '只有': 248,
#  '理由': 248,
#  '之前': 247,
#  '東元': 247,
#  '整體': 247,
#  '賣出': 246,
#  '上市': 245,
#  '他們': 244,
#  '運算': 243,
#  '金像電': 243,
#  '台北': 242,
#  '精選': 242,
#  '最後': 241,
#  '持有': 240,
#  '股東數': 240,
#  '證交所': 240,
#  '華城': 239,
#  '一下': 238,
#  '台塑': 238,
#  '顯示': 236,
#  '受惠': 236,
#  '類免': 236,
#  '行情': 236,
#  '希望': 235,
#  '新台幣': 235,
#  '一樣': 234,
#  '散戶': 234,
#  '中興電': 233,
#  '展望': 233,
#  '超微': 233,
#  '時候': 231,
#  '景氣': 231,
#  '競爭': 231,
#  '晶圓廠': 231,
#  '進入': 231,
#  'AMD': 230,
#  '家數': 230,
#  '領域': 229,
#  '工業': 228,
#  'the': 228,
#  '相對': 228,
#  '方面': 228,
#  '非常': 228,
#  '推出': 227,
#  '彰銀': 227,
#  '華新': 227,
#  '不要': 227,
#  '研發': 226,
#  '新光金': 225,
#  '支出': 223,
#  '除了': 223,
#  '是否': 223,
#  '一年': 223,
#  '啟碁': 223,
#  '升息': 223,
#  '代表': 222,
#  '集團': 221,
#  '出口': 221,
#  '提升': 221,
#  '刪除': 221,
#  'iPhone': 221,
#  '業務': 220,
#  '大同': 217,
#  '國家': 217,
#  '高雄': 217,
#  '世芯': 216,
#  '大聯大': 216,
#  '旺宏': 214,
#  '擴大': 214,
#  '採用': 214,
#  '台新金': 214,
#  '大陸': 213,
#  '這是': 213,
#  '平均': 212,
#  '減少': 212,
#  '研究': 212,
#  '加碼': 211,
#  '黃仁': 211,
#  '開發': 211,
#  '報告': 211,
#  '宣布': 209,
#  'CoWoS': 209,
#  '而且': 208,
#  '趨勢': 208,
#  '材料': 207,
#  '無法': 207,
#  '零股': 207,
#  '熊本': 206,
#  '謝謝': 206,
#  '布局': 206,
#  '結果': 205,
#  '年底': 204,
#  '左右': 204,
#  '滬深': 204,
#  '否則': 202,
#  '設廠': 202,
#  '馬斯克': 201,
#  '緯穎': 200,
#  '能源': 199,
#  '員工': 199,
#  '跌停': 199,
#  '人士': 198,
#  '定穎': 197,
#  '目標': 197,
#  '隨著': 197,
#  '這次': 195,
#  '基本面': 194,
#  '佳世達': 194,
#  '服務': 193,
#  '威盛': 193,
#  '謝金河': 193,
#  '最大': 192,
#  '一定': 192,
#  '瑞昱': 192,
#  '智能': 192,
#  '高點': 192,
#  '至於': 191,
#  '明顯': 191,
#  '記憶體': 191,
#  '不動產': 190,
#  '中華': 190,
#  '什麼': 190,
#  '富時': 189,
#  '巴菲特': 189,
#  '穩定': 189,
#  '華南金': 189,
#  '透過': 189,
#  '力成': 189,
#  '健鼎': 188,
#  'US': 188,
#  'on': 186,
#  '規模': 186,
#  '然後': 185,
#  'NVIDIA': 185,
#  '另外': 184,
#  '殖利率': 184,
#  '交易所': 184,
#  '強調': 183,
#  '成分股': 183,
#  '操作': 183,
#  '政治': 183,
#  '有望': 183,
#  '建廠': 182,
#  '中華電': 182,
#  'EPS': 182,
#  '處份': 182,
#  '華碩': 182,
#  'TSLAUS': 182,
#  '業界': 182,
#  '建準': 182,
#  '未依': 181,
#  'HK': 180,
#  '全年': 180,
#  '聯強': 180,
#  '停損價': 180,
#  '領先': 179,
#  '建議': 179,
#  '企銀': 179,
#  '原因': 179,
#  '大幅': 179,
#  'ctrly': 179,
#  '股號': 179,
#  '股名': 179,
#  '文處份': 178,
#  '火星': 178,
#  '金融': 178,
#  '族群': 178,
#  '透露': 178,
#  'CN': 177,
#  '漢翔': 177,
#  '南亞': 177,
#  '若非': 177,
#  '復甦': 177,
#  'JP': 176,
#  '工程': 176,
#  '一些': 176,
#  '導致': 176,
#  '規處份': 176,
#  '依板': 176,
#  '文未': 176,
#  '許多': 175,
#  '反彈': 175,
#  '優勢': 175,
#  'KR': 175,
#  '先前': 175,
#  '概念股': 174,
#  '這種': 174,
#  '大戶': 174,
#  '補助': 174,
#  '觀察': 174,
#  '關注': 173,
#  '工具': 173,
#  '中芯': 173,
#  '關係': 173,
#  '亞泥': 173,
#  'IC': 173,
#  '本益比': 172,
#  '百張': 172,
#  '挑戰': 171,
#  '微軟': 171,
#  '能力': 171,
#  '大概': 171,
#  '計算': 170,
#  '毛利率': 169,
#  '只要': 169,
#  '上述': 169,
#  'GG': 169,
#  '投入': 169,
#  '遠東新': 169,
#  '出貨': 168,
#  '受到': 168,
#  '南電': 168,
#  '龍頭': 168,
#  '達到': 168,
#  '政策': 168,
#  '華為': 167,
#  '千張': 166,
#  '更多': 166,
#  '上海': 166,
#  '加權': 166,
#  '街口': 166,
#  '工作': 165,
#  '策略': 165,
#  '至少': 165,
#  '此外': 165,
#  '進一步': 165,
#  '瑞儀': 164,
#  '全新': 163,
#  '萬海': 163,
#  '布蘭特': 163,
#  '業績': 162,
#  '相當': 162,
#  '媒體': 162,
#  '魏哲家': 162,
#  '工廠': 161,
#  '強勁': 161,
#  '下滑': 161,
#  '台指期': 160,
#  '積極': 160,
#  '項目': 160,
#  '創新': 160,
#  '尤其': 159,
#  '第四季': 159,
#  '傳出': 159,
#  '地緣': 159,
#  '降息': 159,
#  '正在': 159,
#  '網站': 158,
#  '收盤': 158,
#  '價值': 158,
#  '文曄': 158,
#  '特選': 158,
#  '準備': 158,
#  '康舒': 158,
#  '預測': 158,
#  '衰退': 158,
#  '八大': 158,
#  '本周': 158,
#  '第三季': 157,
#  '針對': 157,
#  '萬元': 156,
#  '來到': 156,
#  '遠傳': 156,
#  '效能': 156,
#  '執行長': 156,
#  '合庫金': 156,
#  '供應商': 155,
#  '三大': 155,
#  '致伸': 155,
#  '微星': 154,
#  '群光': 154,
#  '不能': 154,
#  '連續': 154,
#  '德國': 154,
#  '費城': 154,
#  '華泰': 154,
#  '地位': 154,
#  '介面': 154,
#  '分別': 153,
#  '支持': 153,
#  '一點': 153,
#  '昨天': 152,
#  '帶來': 151,
#  '神達': 151,
#  '智邦': 151,
#  '所有': 150,
#  '大亞': 150,
#  '通知': 150,
#  '解決': 149,
#  '國企': 149,
#  '跌幅': 149,
#  '優於': 149,
#  '至上': 148,
#  '良率': 148,
#  '短期': 148,
#  '提高': 148,
#  '提到': 148,
#  '美光': 148,
#  '大成鋼': 147,
#  'Intel': 147,
#  '電腦': 146,
#  '因素': 146,
#  'TSM': 146,
#  '系統': 145,
#  '面臨': 145,
#  '綜合': 145,
#  '園區': 145,
#  '完成': 145,
#  '利多': 145,
#  '獲得': 145,
#  '第二季': 145,
#  'from': 144,
#  '神基': 144,
#  '題材': 144,
#  '相信': 143,
#  '上半年': 143,
#  '樂觀': 143,
#  '經濟日報': 143,
#  '決定': 143,
#  '投顧': 143,
#  '動能': 143,
#  '裕民': 142,
#  '修正': 142,
#  '通膨': 142,
#  '壓力': 142,
#  '開盤': 142,
#  '類股': 142,
#  '架構': 142,
#  '下修': 142,
#  '矽統': 142,
#  '大跌': 142,
#  '或是': 141,
#  '留言': 141,
#  '公股': 141,
#  '恒生': 141,
#  '成交值': 141,
#  '車用': 140,
#  '震盪': 140,
#  '填息': 139,
#  '走勢': 139,
#  '出來': 139,
#  '士電': 139,
#  '不用': 139,
#  '代工廠': 139,
#  '協助': 138,
#  '規劃': 138,
#  '停利': 138,
#  'and': 138,
#  '東陽': 138,
#  '汽車': 138,
#  '華孚': 137,
#  '新興': 137,
#  '當時': 137,
#  '實現': 137,
#  '第一季': 137,
#  '資產': 137,
#  '劉德音': 137,
#  '利率': 136,
#  '根本': 136,
#  '原本': 136,
#  '寶成': 136,
#  '降低': 136,
#  '幾乎': 136,
#  '商銀': 136,
#  'my': 135,
#  '如何': 135,
#  '成功': 135,
#  'of': 134,
#  '確定': 133,
#  '仟元': 133,
#  '信心': 132,
#  '跌破': 132,
#  '每年': 132,
#  '排列': 132,
#  '各位': 132,
#  '下降': 132,
#  'Sent': 131,
#  '看來': 131,
#  '圖片': 131,
#  '這波': 131,
#  '後續': 131,
#  '空間': 130,
#  '科技股': 130,
#  '加速': 130,
#  '國內': 130,
#  '方案': 130,
#  '完全': 130,
#  '亞力': 129,
#  '供應': 129,
#  '管理': 129,
#  '融券': 128,
#  '夥伴': 128,
#  'PC': 128,
#  '每股': 128,
#  '處理器': 127,
#  '成熟': 127,
#  '短線': 127,
#  '一堆': 127,
#  '為什麼': 127,
#  '一度': 127,
#  '將在': 127,
#  '不少': 127,
#  '裕隆': 127,
#  '造成': 126,
#  '模型': 126,
#  '儘管': 126,
#  '韓國': 126,
#  '越南': 125,
#  '除息': 125,
#  'ESG': 125,
#  '分享': 125,
#  '高達': 125,
#  '取得': 125,
#  '若有': 125,
#  '基本': 125,
#  '不錯': 125,
#  '善用': 125,
#  '估計': 124,
#  '管制': 124,
#  '綠電': 124,
#  '大立光': 124,
#  '不斷': 124,
#  '虧損': 124,
#  '比重': 123,
#  '評估': 123,
#  '看法': 123,
#  '再度': 123,
#  '多頭': 122,
#  'nm': 122,
#  'to': 122,
#  '興建': 122,
#  '盤中': 122,
#  '高通': 122,
#  '上升': 122,
#  '電價': 122,
#  '指標': 122,
#  '補貼': 121,
#  '新唐': 121,
#  '道瓊': 121,
#  '日前': 120,
#  '終端': 120,
#  '香港': 120,
#  '正新': 120,
#  '增長': 120,
#  '中工': 120,
#  '來自': 120,
#  '生成': 120,
#  '為了': 120,
#  '前日': 120,
#  '貢獻': 120,
#  '考慮': 120,
#  '大摩': 120,
#  '變化': 120,
#  '限制': 119,
#  '用電': 119,
#  '償還': 119,
#  '世紀': 119,
#  '機構': 119,
#  '擁有': 119,
#  '慧洋': 119,
#  '櫃檯': 119,
#  '宏達電': 118,
#  '好讀': 118,
#  'Google': 118,
#  '可成': 118,
#  '還在': 118,
#  '選擇': 118,
#  '現金券': 117,
#  '核心': 117,
#  '考量': 117,
#  '機率': 117,
#  '當然': 117,
#  '高階': 116,
#  '股網': 116,
#  '這麼': 116,
#  '總統': 116,
#  '擔心': 116,
#  '同期': 116,
#  '方式': 115,
#  '祥碩': 115,
#  '變成': 115,
#  '台幣': 115,
#  '創下': 115,
#  '系列': 115,
#  '反而': 115,
#  '公司債': 115,
#  'CPU': 114,
#  '定期': 114,
#  '臻鼎': 114,
#  '聯準會': 114,
#  '作為': 114,
#  '南韓': 114,
#  '旗下': 114,
#  '期間': 113,
#  '年減': 113,
#  '高雄廠': 113,
#  '歐洲': 113,
#  '熱門': 113,
#  '回檔': 113,
#  '比例': 113,
#  '網路': 113,
#  '大型': 113,
#  '超越': 113,
#  '平台': 113,
#  '特別': 113,
#  '疫情': 113,
#  '累計': 112,
#  '狀況': 112,
#  '能夠': 112,
#  '收入': 112,
#  '張忠謀': 112,
#  '要求': 112,
#  '這一': 112,
#  '飛宏': 111,
#  '利用率': 111,
#  '首季': 111,
#  '注意': 111,
#  '公開': 110,
#  '雄獅': 110,
#  '專家': 110,
#  '交易日': 110,
#  '重點': 110,
#  '部門': 109,
#  '低碳': 109,
#  '昨日': 109,
#  '重新': 109,
#  '超級': 108,
#  '整理': 108,
#  '早盤': 108,
#  '幾年': 108,
#  '年增': 108,
#  '中鴻': 108,
#  '速度': 107,
#  'in': 107,
#  '條件': 107,
#  '將會': 107,
#  '綠能': 107,
#  '通過': 107,
#  '收益': 107,
#  '發生': 106,
#  '實際': 106,
#  '有限': 106,
#  '中環': 106,
#  '而言': 106,
#  '印度': 106,
#  '值得': 105,
#  '看看': 105,
#  '那麼': 105,
#  '期待': 105,
#  '明天': 105,
#  '成立': 105,
#  '銷售': 105,
#  '拉回': 104,
#  '晶豪科': 104,
#  '財務': 104,
#  '中科': 104,
#  '低於': 104,
#  '一起': 104,
#  '法案': 104,
#  '年度': 104,
#  '高於': 103,
#  '萬張': 103,
#  '高力': 103,
#  '而已': 103,
#  '不僅': 103,
#  '成交': 103,
#  '相較': 103,
#  '保羅': 103,
#  '日後': 103,
#  '快速': 102,
#  '賺錢': 102,
#  '上市櫃': 102,
#  '兆元': 102,
#  '即將': 102,
#  '環境': 102,
#  '收在': 102,
#  '面板': 102,
#  '一波': 102,
#  '回到': 102,
#  '公告': 102,
#  '提出': 102,
#  '同樣': 102,
#  '土地': 101,
#  '進度': 101,
#  '說明': 101,
#  '日圓': 101,
#  '結束': 101,
#  '聚陽': 101,
#  '創新高': 101,
#  '低點': 101,
#  '總裁': 101,
#  '終場': 101,
#  '為主': 101,
#  '推動': 101,
#  '全面': 100,
#  '永豐': 100,
#  '再生': 100,
#  '淨值': 100,
#  '當地': 100,
#  '不如': 99,
#  '權重': 99,
#  '正式': 99,
#  '財測': 99,
#  '月底': 99,
#  '網友': 98,
#  '團隊': 98,
#  '雲品': 98,
#  '人數': 98,
#  '遠東': 98,
#  '長老': 98,
#  '努力': 98,
#  '營業': 98,
#  '吸引': 98,
#  '發表': 97,
#  '嘉澤': 97,
#  '台電': 97,
#  '日期': 97,
#  '陸續': 97,
#  '同步': 97,
#  '南茂': 97,
#  '接下來': 97,
#  '創辦人': 97,
#  '一路': 97,
#  '萬股': 97,
#  '安全': 97,
#  '大量': 97,
#  '海外': 97,
#  '亞洲': 97,
#  '看起來': 97,
#  '保守': 96,
#  '競爭力': 96,
#  '新竹': 96,
#  '一次': 96,
#  '公債': 96,
#  '股神': 96,
#  '漲到': 96,
#  '申請': 96,
#  '定額': 96,
#  '危機': 96,
#  '反應': 96,
#  '彩晶': 96,
#  '地方': 96,
#  '循環': 95,
#  '感覺': 95,
#  '參與': 95,
#  '幅度': 95,
#  '健策': 95,
#  '買盤': 95,
#  '重挫': 95,
#  '不同': 95,
#  '中砂': 95,
#  '階段': 95,
#  '鋼鐵': 95,
#  '才能': 95,
#  '畢竟': 94,
#  '對手': 94,
#  'our': 94,
#  '工商時報': 94,
#  '強勢': 94,
#  '合併': 94,
#  '報酬率': 94,
#  '就算': 94,
#  '代號': 94,
#  '本來': 93,
#  '落後': 93,
#  '漢唐': 93,
#  '占比': 93,
#  '好像': 93,
#  '愛普': 93,
#  '到底': 93,
#  '國巨': 93,
#  '毅嘉': 93,
#  '大關': 92,
#  '中磊': 92,
#  '報酬': 92,
#  '三陽': 92,
#  'Nvidia': 92,
#  '會不會': 92,
#  'JPTT': 92,
#  '之間': 91,
#  '測試': 91,
#  '主力': 91,
#  '引發': 91,
#  '確實': 91,
#  ...}

# %%
# 繪製文字雲
wordcloud = WordCloud(background_color = 'white', width = 800, height = 400, max_words = 50, font_path = font_path)
wordcloud.generate_from_frequencies(freq_dict)

plt.figure(figsize = (10,7))
plt.imshow(wordcloud)
plt.axis('off')
plt.show()

# %% [markdown]
# ### 2.7 移除停用字

# %%
# 以檔案形式匯入通用的停用字檔案
# 將stopwords存成list
stopwords = [line.strip() for line in open('dict/stopwords.txt', 'r', encoding='utf-8').readlines()]

# %% [markdown]
# 移除dataframe中的停用字

# %%
noStop_df = word_df[~word_df['word'].isin(stopwords)]
noStop_df.head(10)
# Out:
#                  artTitle              artDate  \
# 0  [標的]00712富時不動產天天大溢價要賣？  2023-03-20 10:32:54
# 0  [標的]00712富時不動產天天大溢價要賣？  2023-03-20 10:32:54
# 0  [標的]00712富時不動產天天大溢價要賣？  2023-03-20 10:32:54
# 1  [標的]00712富時不動產天天大溢價要賣？  2023-03-20 10:32:54
# 2  [標的]00712富時不動產天天大溢價要賣？  2023-03-20 10:32:54
# 2  [標的]00712富時不動產天天大溢價要賣？  2023-03-20 10:32:54
# 4  [標的]00712富時不動產天天大溢價要賣？  2023-03-20 10:32:54
# 4  [標的]00712富時不動產天天大溢價要賣？  2023-03-20 10:32:54
# 6  [標的]00712富時不動產天天大溢價要賣？  2023-03-20 10:32:54
# 6  [標的]00712富時不動產天天大溢價要賣？  2023-03-20 10:32:54
#
#                                           artContent word
# 0  1. 標的： 00712 富時不動產\r\n(例 2330.TW 台積電)\r\n2. 分類...   標的
# 0  1. 標的： 00712 富時不動產\r\n(例 2330.TW 台積電)\r\n2. 分類...   富時
# 0  1. 標的： 00712 富時不動產\r\n(例 2330.TW 台積電)\r\n2. 分類...  不動產
# 1  1. 標的： 00712 富時不動產\r\n(例 2330.TW 台積電)\r\n2. 分類...   TW
# 2  1. 標的： 00712 富時不動產\r\n(例 2330.TW 台積電)\r\n2. 分類...   分類
# 2  1. 標的： 00712 富時不動產\r\n(例 2330.TW 台積電)\r\n2. 分類...   討論
# 4  1. 標的： 00712 富時不動產\r\n(例 2330.TW 台積電)\r\n2. 分類...   分析
# 4  1. 標的： 00712 富時不動產\r\n(例 2330.TW 台積電)\r\n2. 分類...   正文
# 6  1. 標的： 00712 富時不動產\r\n(例 2330.TW 台積電)\r\n2. 分類...   超過
# 6  1. 標的： 00712 富時不動產\r\n(例 2330.TW 台積電)\r\n2. 分類...   一周

# %% [markdown]
# ### 計算去除停用字後的詞頻

# %% [markdown]
# #### 再次繪製長條圖

# %%
freq_df_nostop = pd.DataFrame(pd.value_counts(noStop_df['word'])).sort_values(by = ['count'], ascending = False).reset_index()

freq_df_nostop.head(10).plot.barh(x = 'word', y = 'count').invert_yaxis()
plt.show()
# Out:
# C:\Users\eddie\AppData\Local\Temp\ipykernel_36952\1312150138.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   freq_df_nostop = pd.DataFrame(pd.value_counts(noStop_df['word'])).sort_values(by = ['count'], ascending = False).reset_index()

# %% [markdown]
# #### 再次繪製文字雲

# %%
freq_dict_nostop = freq_df_nostop.set_index('word').to_dict()
freq_dict_nostop = freq_dict_nostop['count']

# 繪製文字雲
wordcloud_nostop = WordCloud(background_color = 'white', width = 800, height = 400, font_path = font_path, max_words = 50)
wordcloud_nostop.generate_from_frequencies(freq_dict_nostop)

plt.figure(figsize = (10,7))
plt.imshow(wordcloud_nostop)
plt.axis('off')
plt.show()

# %% [markdown]
# ### 2.8 更新停用字字典

# %%
# 參數形式手動加入停用字
stopwords_manual = ["原文", "標題", "今年", "來源", "公司", "評論", "署名", "內容時間", "現在", "連結", "目前", "股票",
                    "股價", "台積電", "台積", "台股", "台灣", "台灣股市", "台灣股票", "台灣股價", "台灣股票市場",
                    "台灣股市", "內容", "評論", "文章", "內文", "記者", "指出", "心得", "來源", "市場", "表示", "去年",
                    "預期", "億元", "TW", "持續", "未來", "產業", "券增", "排行", "證券", "今天", "報導", "分類",
                    "網址", "時間", "客戶", "認為", "討論", "張數", "相關", "影響", "機制", "億美元", "美元", "企業",
                    "金額", "資料", "發布", "格式", "投資"]

stopwords.extend(stopwords_manual)

# %%
noStop_df_2 = noStop_df[~noStop_df['word'].isin(stopwords)]
noStop_df_2.head(10)
# Out:
#                  artTitle              artDate  \
# 0  [標的]00712富時不動產天天大溢價要賣？  2023-03-20 10:32:54
# 0  [標的]00712富時不動產天天大溢價要賣？  2023-03-20 10:32:54
# 0  [標的]00712富時不動產天天大溢價要賣？  2023-03-20 10:32:54
# 4  [標的]00712富時不動產天天大溢價要賣？  2023-03-20 10:32:54
# 4  [標的]00712富時不動產天天大溢價要賣？  2023-03-20 10:32:54
# 6  [標的]00712富時不動產天天大溢價要賣？  2023-03-20 10:32:54
# 6  [標的]00712富時不動產天天大溢價要賣？  2023-03-20 10:32:54
# 6  [標的]00712富時不動產天天大溢價要賣？  2023-03-20 10:32:54
# 7  [標的]00712富時不動產天天大溢價要賣？  2023-03-20 10:32:54
# 7  [標的]00712富時不動產天天大溢價要賣？  2023-03-20 10:32:54
#
#                                           artContent word
# 0  1. 標的： 00712 富時不動產\r\n(例 2330.TW 台積電)\r\n2. 分類...   標的
# 0  1. 標的： 00712 富時不動產\r\n(例 2330.TW 台積電)\r\n2. 分類...   富時
# 0  1. 標的： 00712 富時不動產\r\n(例 2330.TW 台積電)\r\n2. 分類...  不動產
# 4  1. 標的： 00712 富時不動產\r\n(例 2330.TW 台積電)\r\n2. 分類...   分析
# 4  1. 標的： 00712 富時不動產\r\n(例 2330.TW 台積電)\r\n2. 分類...   正文
# 6  1. 標的： 00712 富時不動產\r\n(例 2330.TW 台積電)\r\n2. 分類...   超過
# 6  1. 標的： 00712 富時不動產\r\n(例 2330.TW 台積電)\r\n2. 分類...   一周
# 6  1. 標的： 00712 富時不動產\r\n(例 2330.TW 台積電)\r\n2. 分類...   溢價
# 7  1. 標的： 00712 富時不動產\r\n(例 2330.TW 台積電)\r\n2. 分類...   急速
# 7  1. 標的： 00712 富時不動產\r\n(例 2330.TW 台積電)\r\n2. 分類...   下跌

# %% [markdown]
# ### 2.9 更新斷詞字典
# 更新斷詞字典有兩種方法

# %% [markdown]
# a. 自行定義的斷詞字典

# %%
# 載入自定義辭典：一個詞一行，每行分詞語、詞頻(可省)、詞性(可省)
jieba.load_userdict("dict/user_dict.txt")

# %% [markdown]
# #### 重新斷詞

# %%
# sent_df是還沒斷詞過的df
word_df_updated = sent_df.assign(word = sent_df['sentence'].apply(jieba.lcut)).explode('word').drop(['sentence'], axis=1)

#把長度小於1的row刪掉
word_df_updated = word_df_updated.loc[word_df_updated['word'].str.len()>1]
word_df_updated
# Out:
#                       artTitle              artDate  \
# 0       [標的]00712富時不動產天天大溢價要賣？  2023-03-20 10:32:54
# 0       [標的]00712富時不動產天天大溢價要賣？  2023-03-20 10:32:54
# 0       [標的]00712富時不動產天天大溢價要賣？  2023-03-20 10:32:54
# 1       [標的]00712富時不動產天天大溢價要賣？  2023-03-20 10:32:54
# 1       [標的]00712富時不動產天天大溢價要賣？  2023-03-20 10:32:54
# ...                        ...                  ...
# 238508      [標的]6667信紘科海外擴大營運多  2024-03-19 23:48:36
# 238508      [標的]6667信紘科海外擴大營運多  2024-03-19 23:48:36
# 238508      [標的]6667信紘科海外擴大營運多  2024-03-19 23:48:36
# 238508      [標的]6667信紘科海外擴大營運多  2024-03-19 23:48:36
# 238508      [標的]6667信紘科海外擴大營運多  2024-03-19 23:48:36
#
#                                                artContent     word
# 0       1. 標的： 00712 富時不動產\r\n(例 2330.TW 台積電)\r\n2. 分類...       標的
# 0       1. 標的： 00712 富時不動產\r\n(例 2330.TW 台積電)\r\n2. 分類...       富時
# 0       1. 標的： 00712 富時不動產\r\n(例 2330.TW 台積電)\r\n2. 分類...      不動產
# 1       1. 標的： 00712 富時不動產\r\n(例 2330.TW 台積電)\r\n2. 分類...       TW
# 1       1. 標的： 00712 富時不動產\r\n(例 2330.TW 台積電)\r\n2. 分類...      台積電
# ...                                                   ...      ...
# 238508  1. 標的： 6667 信紘科\r\n\r\n2. 分類：多/空/請益/心得\r\n\r\n...     JPTT
# 238508  1. 標的： 6667 信紘科\r\n\r\n2. 分類：多/空/請益/心得\r\n\r\n...       on
# 238508  1. 標的： 6667 信紘科\r\n\r\n2. 分類：多/空/請益/心得\r\n\r\n...       my
# 238508  1. 標的： 6667 信紘科\r\n\r\n2. 分類：多/空/請益/心得\r\n\r\n...  Samsung
# 238508  1. 標的： 6667 信紘科\r\n\r\n2. 分類：多/空/請益/心得\r\n\r\n...      SMS
#
# [472419 rows x 4 columns]

# %% [markdown]
# #### 重新移除停用字

# %%
nostop_df_updated = word_df_updated[~word_df_updated['word'].isin(stopwords)]

nostop_df_updated
# Out:
#                       artTitle              artDate  \
# 0       [標的]00712富時不動產天天大溢價要賣？  2023-03-20 10:32:54
# 0       [標的]00712富時不動產天天大溢價要賣？  2023-03-20 10:32:54
# 0       [標的]00712富時不動產天天大溢價要賣？  2023-03-20 10:32:54
# 4       [標的]00712富時不動產天天大溢價要賣？  2023-03-20 10:32:54
# 4       [標的]00712富時不動產天天大溢價要賣？  2023-03-20 10:32:54
# ...                        ...                  ...
# 238508      [標的]6667信紘科海外擴大營運多  2024-03-19 23:48:36
# 238508      [標的]6667信紘科海外擴大營運多  2024-03-19 23:48:36
# 238508      [標的]6667信紘科海外擴大營運多  2024-03-19 23:48:36
# 238508      [標的]6667信紘科海外擴大營運多  2024-03-19 23:48:36
# 238508      [標的]6667信紘科海外擴大營運多  2024-03-19 23:48:36
#
#                                                artContent     word
# 0       1. 標的： 00712 富時不動產\r\n(例 2330.TW 台積電)\r\n2. 分類...       標的
# 0       1. 標的： 00712 富時不動產\r\n(例 2330.TW 台積電)\r\n2. 分類...       富時
# 0       1. 標的： 00712 富時不動產\r\n(例 2330.TW 台積電)\r\n2. 分類...      不動產
# 4       1. 標的： 00712 富時不動產\r\n(例 2330.TW 台積電)\r\n2. 分類...       分析
# 4       1. 標的： 00712 富時不動產\r\n(例 2330.TW 台積電)\r\n2. 分類...       正文
# ...                                                   ...      ...
# 238508  1. 標的： 6667 信紘科\r\n\r\n2. 分類：多/空/請益/心得\r\n\r\n...     JPTT
# 238508  1. 標的： 6667 信紘科\r\n\r\n2. 分類：多/空/請益/心得\r\n\r\n...       on
# 238508  1. 標的： 6667 信紘科\r\n\r\n2. 分類：多/空/請益/心得\r\n\r\n...       my
# 238508  1. 標的： 6667 信紘科\r\n\r\n2. 分類：多/空/請益/心得\r\n\r\n...  Samsung
# 238508  1. 標的： 6667 信紘科\r\n\r\n2. 分類：多/空/請益/心得\r\n\r\n...      SMS
#
# [349902 rows x 4 columns]

# %% [markdown]
# 將字詞加入斷詞字典中可以設定該詞的詞頻，如果一個新詞的詞頻較高，它將更有可能被視為一個獨立的單詞，而不是被切分為多個子詞。
#
# 接下來我們試試看在斷詞字典中加入詞頻的話會怎麼樣

# %%
# 加入斷詞字典
jieba.add_word('金融市場', freq=500)

# 查看目前出現幾次
nostop_df_updated[nostop_df_updated['word'] == '金融市場']['word'].count()
# Out:
# 13

# %% [markdown]
# 重新進行斷詞及清除停用字

# %%
# sent_df是還沒斷詞過的df
word_df_updated = sent_df.assign(word = sent_df['sentence'].apply(jieba.lcut)).explode('word').drop(['sentence'], axis=1)

#把長度小於1的row刪掉
word_df_updated = word_df_updated.loc[word_df_updated['word'].str.len()>1]

#去除停用字
nostop_df_updated = word_df_updated[~word_df_updated['word'].isin(stopwords)]

nostop_df_updated.head(10)
# Out:
#                  artTitle              artDate  \
# 0  [標的]00712富時不動產天天大溢價要賣？  2023-03-20 10:32:54
# 0  [標的]00712富時不動產天天大溢價要賣？  2023-03-20 10:32:54
# 0  [標的]00712富時不動產天天大溢價要賣？  2023-03-20 10:32:54
# 4  [標的]00712富時不動產天天大溢價要賣？  2023-03-20 10:32:54
# 4  [標的]00712富時不動產天天大溢價要賣？  2023-03-20 10:32:54
# 6  [標的]00712富時不動產天天大溢價要賣？  2023-03-20 10:32:54
# 6  [標的]00712富時不動產天天大溢價要賣？  2023-03-20 10:32:54
# 6  [標的]00712富時不動產天天大溢價要賣？  2023-03-20 10:32:54
# 7  [標的]00712富時不動產天天大溢價要賣？  2023-03-20 10:32:54
# 7  [標的]00712富時不動產天天大溢價要賣？  2023-03-20 10:32:54
#
#                                           artContent word
# 0  1. 標的： 00712 富時不動產\r\n(例 2330.TW 台積電)\r\n2. 分類...   標的
# 0  1. 標的： 00712 富時不動產\r\n(例 2330.TW 台積電)\r\n2. 分類...   富時
# 0  1. 標的： 00712 富時不動產\r\n(例 2330.TW 台積電)\r\n2. 分類...  不動產
# 4  1. 標的： 00712 富時不動產\r\n(例 2330.TW 台積電)\r\n2. 分類...   分析
# 4  1. 標的： 00712 富時不動產\r\n(例 2330.TW 台積電)\r\n2. 分類...   正文
# 6  1. 標的： 00712 富時不動產\r\n(例 2330.TW 台積電)\r\n2. 分類...   超過
# 6  1. 標的： 00712 富時不動產\r\n(例 2330.TW 台積電)\r\n2. 分類...   一周
# 6  1. 標的： 00712 富時不動產\r\n(例 2330.TW 台積電)\r\n2. 分類...   溢價
# 7  1. 標的： 00712 富時不動產\r\n(例 2330.TW 台積電)\r\n2. 分類...   急速
# 7  1. 標的： 00712 富時不動產\r\n(例 2330.TW 台積電)\r\n2. 分類...   下跌

# %%
# 查看調整詞頻之後出現幾次
nostop_df_updated[nostop_df_updated['word'] == '金融市場']['word'].count()
# Out:
# 13

# %% [markdown]
# 經過比對可以看到該詞的數量上升，代表該詞更加精準地被拆分了出來。

# %% [markdown]
# #### 重新計算詞頻

# %%
freq_df_updated = pd.DataFrame(pd.value_counts(nostop_df_updated['word'])).sort_values(by = ['count'], ascending = False).reset_index()

freq_df_updated
# Out:
# C:\Users\eddie\AppData\Local\Temp\ipykernel_36952\2024435358.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   freq_df_updated = pd.DataFrame(pd.value_counts(nostop_df_updated['word'])).sort_values(by = ['count'], ascending = False).reset_index()
#       word  count
# 0       AI   2385
# 1       晶片   1843
# 2      半導體   1834
# 3       美國   1617
# 4       奈米   1479
# ...    ...    ...
# 35175  Suk      1
# 35176  碰不到      1
# 35177   收乾      1
# 35178  進一位      1
# 35179  機能水      1
#
# [35180 rows x 2 columns]

# %% [markdown]
# #### 重新繪製詞頻長條圖

# %%
freq_df_updated.head(10).plot.barh(x='word', y='count').invert_yaxis()
plt.show()

# %% [markdown]
# #### 繪製文字雲

# %%
freq_dict_updated = freq_df_updated.set_index('word').to_dict()
freq_dict_updated = freq_dict_updated['count']

# 繪製文字雲
wordcloud_after = WordCloud(background_color='white', width=800, height = 400, font_path = font_path, max_words = 50)
wordcloud_after.generate_from_frequencies(freq_dict_updated)

plt.figure(figsize = (10,7))
plt.imshow(wordcloud_after)
plt.axis('off')
plt.show()

# %% [markdown]
# ### 2.10 比較清理前後的文字雲

# %%
plt.figure(figsize = (14,8))

plt.subplot(1,2,1)
plt.imshow(wordcloud)
plt.axis('off')

plt.subplot(1,2,2)
plt.imshow(wordcloud_after)
plt.axis('off')

plt.show()

# %% [markdown]
# 資料清理的過程往往是花費做多時間的工程，因為在做完第一次的斷詞、正規化、清除停用字後，我們會發現還是會有許多不重要的字沒有被清理到，或是有些兩個字以上的專有名詞、名詞片語被斷開，因此在進行資料分析前，必須不斷經歷以上過程，更新停用字、字典，以便在後續的分析中能得到重要且正確的分析結果

# %%
# !pip freeze > requirements.txt
